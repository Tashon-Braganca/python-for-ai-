# %%
print("hello world")

# %%
a=int(input("enter a val: "))
b=int(input("enter seoncd value:"))
sum=a+b
print(sum)
print(sum/2)
print("Hello", 1,2.3,True)

# %%
print("Hello", 1,2.3,True,sep='/')
print

# %% [markdown]
# #2. Data Types

# %%
#integer
print(8)

# %%
#List(array of python)
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuple
print((1,2,3,4))
# Out:
# (1, 2, 3, 4)

# %%
#sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dcitionary
print({'name':'Tashon','gender':"Male"})
# Out:
# {'name': 'Tashon', 'gender': 'Male'}

# %%
#type
print(type("tashon"))
print(type(12))
print(type({'name':'Tashon','gender':"Male"}))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'dict'>

# %%
#Variables
name="nitish"
print(name)
# Out:
# nitish

# %%
#dynamic typing 
a=5 # we do nt need to speicfy the type of datatype we are using for the varibla 
#unlike c and c++
int a=19
# Out:
#   Cell In[8], line 4
#     int a=19
#         ^
# SyntaxError: invalid syntax

# %%
#dynamic binidng
a=8
print(a)
a="tashon"
print(a)
# the vairabels haveno specifc storage it jsut needs to be perfeclty locked into what it is uing
#unlike c and c99+++
# Out:
# 8
# tashon

# %%
a,b,c=1,2,3
print(a,b,c) # interesting way to create new variables8


a=b=c=10
print(a,b,c)
# Out:
# 1 2 3
# 10 10 10

# %% [markdown]
# User input

# %%
input()
# Out:
# '789]'

# %%
input('enter email: ')
a=int(input("enter email: ")) # wont work since we exlpictly specified that this is a int
print(type(a))
print(a)

# %%
#literals: aluesinside the variables
a=0b1010 #binary leiterals
b=100 #deciaml leiterals
c=0o310 # octal reporestainton

float_1=10.5
print(float_1)

complex=3.14j
