# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("userData3.csv")
df.columns
# Out:
# Index(['_id', 'firstName', 'lastName', 'phoneNumber', 'status', 'apartmentId',
#        'wltBalance', 'role', 'GMID', 'accountDetails._id', 'CommissionBalance',
#        'otpCount', 'lastOtpTime', 'createdAt', 'updatedAt', 'refreshToken',
#        'mfaEnabled', 'pushNotificationToken', 'platform', 'lastLogin',
#        'referralCode', 'address[0]._id', 'address[0].aptName',
#        'address[0].aptNumber', 'address[0].aptBlock', 'address[0].aptArea',
#        'address[0].status', 'address[0].GMID', 'address[0].__v',
#        'address[0].createdAt', 'address[0].updatedAt', 'ctryId[0]',
#        'address[0].resName', 'address[0].resNumber', 'address[0].userID',
#        'address[0].lat', 'address[0].lng', 'address[0].formattedAddress',
#        'requestedAptName', 'referredByUserId'],
#       dtype='object')

# %%
df.drop_colmumns(Index(['_id', 'firstName', 'lastName', 'phoneNumber', 'status', 'apartmentId',
       'wltBalance', 'role', 'GMID', 'accountDetails._id', 'CommissionBalance',
       'otpCount', 'lastOtpTime', 'createdAt', 'updatedAt', 'refreshToken',
       'mfaEnabled', 'pushNotificationToken', 'platform', 'lastLogin',
       'referralCode', 'address[0]._id', 'address[0].aptName',
       'address[0].aptNumber', 'address[0].aptBlock', 'address[0].aptArea',
       'address[0].status', 'address[0].GMID', 'address[0].__v',
       'address[0].createdAt', 'address[0].updatedAt', 'ctryId[0]',
       'address[0].resName', 'address[0].resNumber', 'address[0].userID',
       'address[0].lat', 'address[0].lng', 'address[0].formattedAddress',
       'requestedAptName', 'referredByUserId'],)
